# %% [markdown]
# # NEAF DIP EXAM
# name: 林鈺洋

# %% [markdown]
# ---
# ### Please achieve the following image transformation: change image A into image B.

# %% [markdown]
# ### keywords:
# cv2.blur(img, (3, 3))
# cv2.dilate(img, kernel)
# cv2.inRange(img, np.array([16, 26, 120]), np.array([74, 255, 255]))
# cv2.calcHist([img], [0], None, [256], [0, 256])
# cv2.equalizeHist(gray_img)
# cv2.bitwise_and(img1, img2, mask)
# cv2.IMREAD_GRAYSCALE
# cv2.drawContours(img, contours, -1, (0, 255, 0), 1)
# cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
# cv2.rectangle(result, (X, Y), (X+W, Y+H), (0, 0, 255), 2)
# cv2.medianBlur(img, 3)
# cv2.boundingRect
# cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
# cv2.threshold(img, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
# cv2.imwrite('123.jpg', img)
# cv2.GaussianBlur(img, (5, 5), 0)
# cv2.erode(img, kernel)
# cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# cv2.contourArea(contour)

# %% [markdown]
# ---

# %% [markdown]
# ### library

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# ---

# %% [markdown]
# ### 1. (3%)
# #### fig.a
# <img src="img/5.jpg" width="20%" heught="20%">
#
# #### fig.b
# <img src="img/6.jpg" width="20%" heught="20%">

# %%
# read image
img_a = cv2.imread("img/5.jpg")

'''
enter your code
'''
img_b = cv2.cvtColor(img_a, cv2.COLOR_BGR2GRAY) 
_, img_b = cv2.threshold(img_b, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)  

# show image
plt.imshow(img_a)
plt.show()
plt.imshow(img_b, 'gray')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 2. (3%)
# #### fig.a
# <img src="img/1.jpg" width="15%" heught="15%">
#
# #### fig.b
# <img src="img/2.jpg" width="15%" heught="15%">

# %%
# read image
img_a = cv2.imread("img/1.jpg",cv2.IMREAD_GRAYSCALE )

'''
enter your code
'''

img_b = cv2.equalizeHist(img_a)  

# show image
plt.imshow(img_a, 'gray')
plt.show()
plt.imshow(img_b, 'gray')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### 3. (4%)
# #### a圖
# <img src="img/3.jpg" width="20%" heught="20%">
#
# #### b圖
# <img src="img/4.jpg" width="20%" heught="20%">

# %%
# read image
img_a = cv2.imread("img/3.jpg")

'''
enter your code
'''

img_b = cv2.medianBlur(img_a, 3) 

# show image
plt.imshow(img_a)
plt.show()
plt.imshow(img_b)
plt.show()

# %% [markdown]
# ### 4. (5%)
# #### fig.a
# <img src="img/7.jpg" width="20%" heught="20%">
#
# #### fig.b
# <img src="img/8.jpg" width="20%" heught="20%">
#
# 1. Find the Beluga Whale contours in the  images.(5%)
# 2. Calculate the countours area.(5%)

# %%
img_a = cv2.imread("img/7.jpg")

'''
enter your code
'''

_, contours = cv2.findContours(img_a, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE) 
img_b = cv2.drawContours(img_a, contours, -1, (0, 255, 0), 1) 
countours_area = cv2.contourArea(contour) 

# show image
plt.imshow(img_a)
plt.show()
plt.imshow(img_b)
plt.show()
print('The Beluga Whale area is ',countours_area)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[43], line 7
#       1 img_a = cv2.imread("img/7.jpg")
#       3 '''
#       4 enter your code
#       5 '''
# ----> 7 _, contours = cv2.findContours(img_a, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#       8 img_b = cv2.drawContours(img_a, contours, -1, (0, 255, 0), 1)
#       9 countours_area = cv2.contourArea(contour)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\contours_new.cpp:335: error: (-2:Unspecified error) in function 'class std::shared_ptr<struct ContourScanner_> __cdecl ContourScanner_::create(class cv::BlockStorage<class cv::Point_<int>,1024,0> &,class cv::BlockStorage<signed char,1024,0> &,class cv::Mat,int,int,class cv::Point_<int>)'
# > Modes other than RETR_FLOODFILL and RETR_CCOMP support only CV_8UC1 images (expected: 'img.type() == CV_8UC1'), where
# >     'img.type()' is 16 (CV_8UC3)
# > must be equal to
# >     'CV_8UC1' is 0 (CV_8UC1)
